# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
nav = pd.read_csv("Data/Processed/02_nav_history_clean.csv")
transactions = pd.read_csv("Data/Processed/08_investor_transactions_clean.csv")
portfolio = pd.read_csv("Data/Processed/09_portfolio_holdings_clean.csv")
performance = pd.read_csv("Data/Processed/07_scheme_performance_clean.csv")

# %%
nav['date'] = pd.to_datetime(nav['date'])

# %%
nav = nav.sort_values(['amfi_code','date'])

nav['daily_return'] = (
    nav.groupby('amfi_code')['nav']
       .pct_change()
)

# %%
results = []

for fund in nav['amfi_code'].unique():

    r = nav[
        nav['amfi_code']==fund
    ]['daily_return'].dropna()

    var95 = np.percentile(r,5)

    cvar95 = r[r <= var95].mean()

    results.append([
        fund,
        var95,
        cvar95
    ])

var_df = pd.DataFrame(
    results,
    columns=[
        'amfi_code',
        'VaR_95',
        'CVaR_95'
    ]
)

# %%
var_df.to_csv(
    "var_cvar_report.csv",
    index=False
)

# %%
top5 = nav['amfi_code'].unique()[:5]

# %%
plt.figure(figsize=(14,6))

for fund in top5:

    temp = nav[
        nav['amfi_code']==fund
    ].copy()

    rolling_sharpe = (
        temp['daily_return']
        .rolling(90)
        .mean()
        /
        temp['daily_return']
        .rolling(90)
        .std()
    ) * np.sqrt(252)

    plt.plot(
        temp['date'],
        rolling_sharpe,
        label=str(fund)
    )

plt.legend()
plt.title("Rolling 90-Day Sharpe")
plt.show()

# %%
plt.savefig(
    "rolling_sharpe_chart.png"
)

# %%
transactions['transaction_date'] = pd.to_datetime(
    transactions['transaction_date']
)

first_txn = (
    transactions
    .groupby('investor_id')
    ['transaction_date']
    .min()
)

cohort = first_txn.dt.year

# %%
transactions['cohort_year'] = (
    transactions['investor_id']
    .map(cohort)
)

# %%
cohort_summary = (
    transactions
    .groupby('cohort_year')['amount_inr']
    .agg(['mean', 'sum'])
)

print(cohort_summary)
# Out:
#                       mean         sum
# cohort_year
# 2024         107422.541832  3491125187
# 2025         109158.577061    30455243

# %%
sip = transactions[
    transactions['transaction_type']
    == 'SIP'
]

# %%
sip = sip.sort_values(
    ['investor_id','transaction_date']
)

sip['gap_days'] = (
    sip.groupby('investor_id')
    ['transaction_date']
    .diff()
    .dt.days
)

# %%
risk = (
    sip.groupby('investor_id')
    ['gap_days']
    .mean()
)

at_risk = risk[
    risk > 35
]

# %%
len(at_risk)
# Out:
# 3825

# %%
scorecard['risk_grade'] = 'Moderate'

scorecard.loc[
    (scorecard['beta_calc'] < 0.8) &
    (scorecard['max_drawdown_calc'] > -15),
    'risk_grade'
] = 'Low'

scorecard.loc[
    (scorecard['beta_calc'] > 1.1) |
    (scorecard['max_drawdown_calc'] < -25),
    'risk_grade'
] = 'High'

# %%
recommend = scorecard[
    scorecard['risk_grade'] == grade
]

# %%
print(scorecard['risk_grade'].value_counts())
# Out:
# risk_grade
# Low         27
# High        10
# Moderate     3
# Name: count, dtype: int64

# %%
scorecard['risk_grade'] == grade
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29    False
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35    False
# 36     True
# 37     True
# 38     True
# 39    False
# Name: risk_grade, dtype: bool

# %%
print(grade)
# Out:
# Low

# %%
recommend = scorecard[
    scorecard['risk_grade'] == grade
]

print(recommend.shape)
recommend.head()
# Out:
# (27, 22)
#    amfi_code      cagr  cagr_pct  sharpe_ratio_calc  sortino_ratio_calc  \
# 0     120505  0.328016     32.80           1.513677            2.602985
# 1     120843  0.308833     30.88           1.711792            3.097183
# 4     119598  0.323981     32.40           1.201269            2.128941
# 5     120504  0.232774     23.28           1.474526            2.593171
# 6     149323  0.295581     29.56           1.494736            2.475688
#
#    max_drawdown_calc  alpha_calc  beta_calc  return_3yr_pct  \
# 0          -0.181885   29.508521  -1.745379           18.08
# 1          -0.129740   27.321126  -0.436989           15.65
# 4          -0.287060   30.314487  -0.350801           23.39
# 5          -0.125883   21.609065  -2.613923           14.41
# 6          -0.172481   26.573262   0.125950           17.16
#
#    expense_ratio_pct  ...  rank_alpha  rank_expense  rank_3yr_score  \
# 0               1.36  ...         3.0          15.0            82.5
# ...

# %%
scorecard.groupby('risk_grade').size()
# Out:
# risk_grade
# High        10
# Low         27
# Moderate     3
# dtype: int64

# %%
print(grade)
print(scorecard['risk_grade'].value_counts())
# Out:
# Low
# risk_grade
# Low         27
# High        10
# Moderate     3
# Name: count, dtype: int64

# %%
top_funds = (
    scorecard[scorecard['risk_grade'] == grade]
    .sort_values('fund_score', ascending=False)
    .head(5)
)

print(top_funds[['amfi_code','fund_score','risk_grade']])
# Out:
#    amfi_code  fund_score risk_grade
# 0     120505      77.500        Low
# 1     120843      77.125        Low
# 4     119598      70.000        Low
# 5     120504      67.625        Low
# 6     149323      65.750        Low

# %%
risk = input("Risk Appetite (Low/Moderate/High): ")

mapping = {
    "Low": "Low",
    "Moderate": "Moderate",
    "High": "High"
}

grade = mapping[risk]

recommend = (
    scorecard[scorecard['risk_grade'] == grade]
    .sort_values('fund_score', ascending=False)
    .head(5)
)

recommend[['amfi_code', 'fund_score', 'risk_grade']]
# Out:
# Risk Appetite (Low/Moderate/High):  Low
#    amfi_code  fund_score risk_grade
# 0     120505      77.500        Low
# 1     120843      77.125        Low
# 4     119598      70.000        Low
# 5     120504      67.625        Low
# 6     149323      65.750        Low

# %%
hhi = (
    portfolio
    .groupby('amfi_code')
    ['weight_pct']
    .apply(
        lambda x:
        (x/100).pow(2).sum()
    )
)

# %%
hhi = hhi.reset_index()

hhi.columns = [
    'amfi_code',
    'HHI'
]

# %%
hhi.head(10)
# Out:
#    amfi_code       HHI
# 0     100016  0.139534
# 1     100033  0.147592
# 2     101206  0.129332
# 3     101207  0.200700
# 4     102885  0.174709
# 5     102886  0.114693
# 6     102887  0.129805
# 7     118632  0.168298
# 8     118633  0.121461
# 9     118634  0.108358

# %%
hhi.sort_values(
    'HHI',
    ascending=False
).head(10)
# Out:
#     amfi_code       HHI
# 11     119092  0.206448
# 3      101207  0.200700
# 18     119599  0.174751
# 4      102885  0.174709
# 7      118632  0.168298
# 29     148568  0.167930
# 21     120505  0.157570
# 22     120506  0.153794
# 27     125498  0.152414
# 23     120841  0.149680

# %%
hhi.to_csv(
    "sector_hhi_report.csv",
    index=False
)

# %%
import os

os.path.exists(
    "sector_hhi_report.csv"
)
# Out:
# True

# %%
import matplotlib.pyplot as plt

top_hhi = hhi.sort_values(
    'HHI',
    ascending=False
).head(10)

plt.figure(figsize=(10,5))

plt.bar(
    top_hhi['amfi_code'].astype(str),
    top_hhi['HHI']
)

plt.title("Top 10 Most Concentrated Funds (HHI)")
plt.xlabel("AMFI Code")
plt.ylabel("HHI")

plt.xticks(rotation=45)

plt.show()

# %%
hhi.sort_values('HHI', ascending=False).head()
# Out:
#     amfi_code       HHI
# 11     119092  0.206448
# 3      101207  0.200700
# 18     119599  0.174751
# 4      102885  0.174709
# 7      118632  0.168298

# %%
hhi.to_csv(
    "sector_hhi_report.csv",
    index=False
)

print("sector_hhi_report.csv saved")
# Out:
# sector_hhi_report.csv saved

# %%
import os

for f in os.listdir():
    print(f)
# Out:
# .git
# .ipynb_checkpoints
# Advanced_Analytics.ipynb
# alpha_beta.csv
# anaconda_projects
# benchmark_comparison.png
# bluestock_mf_dashboard.pbix
# cagr_table.csv
# Dashboard
# Data
# data_ingestion.py
# fund_scorecard.csv
# live_nav_fetch.py
# mutual fund dashboard.pbix
# mutual_fund.db
# Notebooks
# README.md
# Reports
# requirements.txt
# rolling_sharpe_chart.png
# scorecard.csv
# sector_hhi_report.csv
# sharpe_ratio.csv
# SQL
# var_cvar_report.csv
